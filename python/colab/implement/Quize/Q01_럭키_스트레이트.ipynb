# %% [markdown]
# <a href="https://colab.research.google.com/github/jaedeokhan/start-coding-test-pratice/blob/main/python/colab/implement/Quize/Q01_%EB%9F%AD%ED%82%A4_%EC%8A%A4%ED%8A%B8%EB%A0%88%EC%9D%B4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 문제 : [구현] p321 럭키 스트레이트

# %% [markdown]
# ### 1. 리스트를 사용한 해결 방법

# %%
### 입력값
N = [123402, 7755, 1234512345, 1234]
###

### 문제
def solution(N):
    
    front = str(N)[:len(str(N)) // 2]
    rear = str(N)[len(str(N)) // 2:]
    
    front_sum = 0 
    rear_sum = 0 

    for i in range(len(str(front))):
        front_sum += int(front[i])
        rear_sum += int(rear[i])

    return 'LUCKY' if front_sum == rear_sum else 'READY'

    
### 출력
for i in range(len(N)):
   print("================================")
   print(f'Start : {i+1}')
   answer = solution(N[i])
   print(f'answer : {answer}')
   print("================================")
# Out:
# ================================
# Start : 1
# answer : LUCKY
# ================================
# ================================
# Start : 2
# answer : READY
# ================================
# ================================
# Start : 3
# answer : LUCKY
# ================================
# ================================
# Start : 4
# answer : READY
# ================================

# %% [markdown]
# ### 2. 리스트 내포식과 sum()을 사용한 해결방법

# %%
### 입력값
N = [123402, 7755, 1234512345, 1234]
###

### 문제
def solution(N):
    
    front = [int(i) for i in str(N)[:len(str(N)) // 2] ] 
    rear = [int(i) for i in str(N)[len(str(N)) // 2:] ]

    return 'LUCKY' if sum(front) == sum(rear) else 'READY'

    
### 출력
for i in range(len(N)):
   print("================================")
   print(f'Start : {i+1}')
   answer = solution(N[i])
   print(f'N : {N[i]} \nanswer : {answer}')
   print("================================")
# Out:
# ================================
# Start : 1
# N : 123402
# answer : LUCKY
# ================================
# ================================
# Start : 2
# N : 7755
# answer : READY
# ================================
# ================================
# Start : 3
# N : 1234512345
# answer : LUCKY
# ================================
# ================================
# Start : 4
# N : 1234
# answer : READY
# ================================

# %% [markdown]
# ### 3. 정답 해설

# %%
### 입력값
N = [123402, 7755, 1234512345, 1234]
###

### 문제
def solution(N):
    
    N = str(N)

    length = len(N)
    summary = 0

    # 왼쪽 부분의 합 더하기
    for i in range(length // 2):
        summary += int(N[i])

    # 오른쪽
    for i in range(length // 2, length):
        summary -= int(N[i])

    return 'LUCKY' if summary == 0 else 'READY'

    
### 출력
for i in range(len(N)):
   print("================================")
   print(f'Start : {i+1}')
   answer = solution(N[i])
   print(f'N : {N[i]} \nanswer : {answer}')
   print("================================")
# Out:
# ================================
# Start : 1
# N : 123402
# answer : LUCKY
# ================================
# ================================
# Start : 2
# N : 7755
# answer : READY
# ================================
# ================================
# Start : 3
# N : 1234512345
# answer : LUCKY
# ================================
# ================================
# Start : 4
# N : 1234
# answer : READY
# ================================
